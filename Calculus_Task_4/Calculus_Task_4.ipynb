# %% [markdown]
# # ВВЕДЕНИЕ В МАТЕМАТИЧЕСКИЙ АНАЛИЗ
# ****************

# %%
import numpy as np
from math import sin
import matplotlib.pyplot as plt
from tqdm import tqdm
from math import sin, exp, e, log, sqrt, pi

# %% [markdown]
# ### Тема “Предел функции”

# %% [markdown]
# #### 1.	Предложить пример функции, не имеющей предела в нуле и в бесконечностях.

# %% [markdown]
# $f(x)=sin(x)+1.1 = (0.1;2.1)$

# %%
x = np.linspace(-30,30,1000)
    
y = np.sin(x)+1.1
    # print(n)
plt.plot(x, y)

# %% [markdown]
# #### 2.	Привести пример функции, не имеющей предела в точке, но определенной в ней.

# %% [markdown]
# $f(x)=e^{\frac{1}{x}}$
#
# $f(x(1))=e^{\frac{1}{1}}=e$

# %% [markdown]
# #### 3.	Исследовать функцию   по плану:
#
# ![image.png](attachment:image.png)
#
# a.	Область задания и область значений.
#
# b.	Нули функции и их кратность.
#
# c.	Отрезки знакопостоянства.
#
# d.	Интервалы монотонности.
#
# e.	Четность функции.
#
# f.	Ограниченность.
#
# g.	Периодичность.

# %% [markdown]
# `Ответ:`
#
# a. $dom(f) = R$ ;  $ran(f) = R$  - Функция определена на всей числовой прямой
#
# b. $f(x) = x^3-x^2=0$,  $x_1 = 0$,  $x_2 = 1$ - Функция обращается в 0 в точках 0 и 1
#
# c. На промежутке $(-\infty;1)$ функция сохраняет отрицательный знак (исключая 0). На $(1;+\infty)$ - положительный
#
# d. На промежутке $(0;\frac{2}{3})$ функция монотонно убывает (строго убывает). На промежутках $(-\infty ;0)$ и $(\frac{2}{3};+\infty)$ - монотонно возрастает (строго возрастает)
#
# e. $f(x) \not= f(-x)$ ; $f(-x) \not= f(-x)$ - Условия четности/нечетности функции не выполняются. Функция общего вида.
#
# f. Сверху и снизу функция неограничена
#
# g. Функция апериодична

# %%
x = np.linspace(-5,5,100)
y = x**3-x**2
plt.plot(x,y)

# %% [markdown]
# #### 4. Найти предел:

# %% [markdown]
# a. ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to 0}\frac{3x^3-2x^2}{4x^2} = \frac{\lim_{x \to 0}(3x^3-2x^2)}{\lim_{x \to 0}(4x^2)} = -\frac{2}{4} = -\frac{1}{2}$

# %% [markdown]
# b. ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to 0}\frac{\sqrt{1+x}-1}{\sqrt[3]{1+x}-1} = \frac{a}{\sqrt[3]{a}} = \frac{3}{1} = 3$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to \infty} \left( \frac{x+3}{x} \right) ^{4x+1} = \left( \frac{\infty}{\infty} \right) ^{\infty} = (1)^{\infty} = 1$

# %% [markdown]
# ### Тема “Теоремы о пределах”

# %% [markdown]
# #### 1. Найти предел:

# %% [markdown]
# a.
# ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to 0}\frac{sin(2x)}{4x} = \frac{1}{2}$

# %% [markdown]
# b.
# ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to 0}\frac{x}{sin(x)} = 1$

# %% [markdown]
# c.
# ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to 0}\frac{x}{arcsin(x)} = 0$

# %% [markdown]
# d. ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to \infty} (\frac{4x+3}{4x-3})^{6x} = 1$

# %% [markdown]
# e. ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to \infty} \frac{sinx+lnx}{x} = 0$

# %% [markdown]
# f. ![image.png](attachment:image.png)

# %% [markdown]
# `Ответ:` $ \lim_{x \to 0} \frac{sinx+lnx}{x} = -\infty$
